# %%
import pandas as pd
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
ipl = pd.read_csv("../data/cleaned/ipl_cleaned.csv")

# %%
# Ensure correct order at ball level
ipl = ipl.sort_values(['batter', 'date', 'match_id', 'over', 'ball']).reset_index(drop=True)

# Rolling runs in last 10 balls
ipl['rolling_runs_10'] = (
    ipl.groupby('batter')['batsman_runs']
       .rolling(window=10, min_periods=1)
       .sum()
       .shift(1)
       .reset_index(level=0, drop=True)
)

# Rolling balls (always 10 but handle start)
ipl['rolling_balls_10'] = (
    ipl.groupby('batter')['ball']
       .rolling(window=10, min_periods=1)
       .count()
       .shift(1)
       .reset_index(level=0, drop=True)
)

# Strike Rate last 10 balls
ipl['rolling_strike_rate_10'] = (
    (ipl['rolling_runs_10'] / ipl['rolling_balls_10']) * 100
)

ipl['rolling_strike_rate_10'] = ipl['rolling_strike_rate_10'].fillna(0)

# %% [markdown]
# #### Match level data seperation - Batsman

# %%
df_batter = ipl.groupby(['match_id','batter','bowler','date','venue','bowling_team']).agg({
    'batsman_runs':'sum',
    'is_wicket':'sum'
}).reset_index()
    
df_batter.head(10)
# Out:
#    match_id       batter      bowler        date                  venue  \
# 0    335982    AA Noffke  AB Agarkar  2008-04-18  M Chinnaswamy Stadium
# 1    335982    AA Noffke  SC Ganguly  2008-04-18  M Chinnaswamy Stadium
# 2    335982      B Akhil  AB Agarkar  2008-04-18  M Chinnaswamy Stadium
# 3    335982  BB McCullum   AA Noffke  2008-04-18  M Chinnaswamy Stadium
# 4    335982  BB McCullum    CL White  2008-04-18  M Chinnaswamy Stadium
# 5    335982  BB McCullum   JH Kallis  2008-04-18  M Chinnaswamy Stadium
# 6    335982  BB McCullum     P Kumar  2008-04-18  M Chinnaswamy Stadium
# 7    335982  BB McCullum    SB Joshi  2008-04-18  M Chinnaswamy Stadium
# 8    335982  BB McCullum      Z Khan  2008-04-18  M Chinnaswamy Stadium
# 9    335982     CL White  AB Agarkar  2008-04-18  M Chinnaswamy Stadium
#
#                   bowling_team  batsman_runs  is_wicket
# 0        Kolkata Knight Riders             2          0
# 1        Kolkata Knight Riders             7          1
# 2        Kolkata Knight Riders             0          1
# 3  Royal Challengers Bangalore            24          0
# 4  Royal Challengers Bangalore            16          0
# 5  Royal Challengers Bangalore            32          0
# 6  Royal Challengers Bangalore            32          0
# 7  Royal Challengers Bangalore            21          0
# 8  Royal Challengers Bangalore            33          0
# 9        Kolkata Knight Riders             3          1

# %% [markdown]
# #### Match level data seperation - Bowler

# %%
df_bowler = (
    ipl.groupby(['match_id', 'bowler', 'date', 'venue', 'bowling_team'])
       .agg(
           balls_bowled=('ball', 'count'),
           wickets=('is_wicket', 'sum'),
           runs_conceded=('batsman_runs', 'sum')
       )
       .reset_index()
)

# %%
df_bowler['overs_bowled'] = df_bowler['balls_bowled'] / 6

# %%
df_bowler = df_bowler.sort_values(['bowler', 'date']).reset_index(drop=True)
df_bowler.head(30)
# Out:
#     match_id          bowler        date  \
# 0     548341  A Ashish Reddy  2012-04-26
# 1     548346  A Ashish Reddy  2012-04-29
# 2     548348  A Ashish Reddy  2012-05-01
# 3     548352  A Ashish Reddy  2012-05-04
# 4     548356  A Ashish Reddy  2012-05-06
# 5     548359  A Ashish Reddy  2012-05-08
# 6     548329  A Ashish Reddy  2012-05-10
# 7     548373  A Ashish Reddy  2012-05-18
# 8     548376  A Ashish Reddy  2012-05-20
# 9     598000  A Ashish Reddy  2013-04-05
# 10    598004  A Ashish Reddy  2013-04-07
# 11    598048  A Ashish Reddy  2013-04-09
# 12    598013  A Ashish Reddy  2013-04-14
# 13    598030  A Ashish Reddy  2013-04-25
# 14    829719  A Ashish Reddy  2015-04-13
# 15    829727  A Ashish Reddy  2015-04-16
# 16    829731  A Ashish Reddy  2015-04-18
# 17    829773  A Ashish Reddy  2015-05-02
# 18    980907  A Ashish Reddy  2016-04-12
# 19    980915  A Ashish Reddy  2016-04-16
# 20   1304083        A Badoni  2022-04-24
# 21   1304109        A Badoni  2022-05-15
# 22   1359512        A Badoni  2023-04-28
# 23   1422122        A Badoni  2024-03-24
# 24   1426295        A Badoni  2024-05-08
# 25    548336      A Chandila  2012-04-23
# 26    548365      A Chandila  2012-05-13
# 27    548373      A Chandila  2012-05-18
# 28    548377      A Chandila  2012-05-20
# 29    598014      A Chandila  2013-04-14
#
#                                                 venue          bowling_team  \
# 0                          Subrata Roy Sahara Stadium       Deccan Chargers
# 1                                    Wankhede Stadium       Deccan Chargers
# 2                                    Barabati Stadium       Deccan Chargers
# 3                     MA Chidambaram Stadium, Chepauk       Deccan Chargers
# 4                               M Chinnaswamy Stadium       Deccan Chargers
# 5           Rajiv Gandhi International Stadium, Uppal       Deccan Chargers
# 6           Rajiv Gandhi International Stadium, Uppal       Deccan Chargers
# 7           Rajiv Gandhi International Stadium, Uppal       Deccan Chargers
# 8           Rajiv Gandhi International Stadium, Uppal       Deccan Chargers
# 9           Rajiv Gandhi International Stadium, Uppal   Sunrisers Hyderabad
# 10          Rajiv Gandhi International Stadium, Uppal   Sunrisers Hyderabad
# 11                              M Chinnaswamy Stadium   Sunrisers Hyderabad
# 12                                       Eden Gardens   Sunrisers Hyderabad
# 13                    MA Chidambaram Stadium, Chepauk   Sunrisers Hyderabad
# 14                              M Chinnaswamy Stadium   Sunrisers Hyderabad
# 15  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...   Sunrisers Hyderabad
# 16  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...   Sunrisers Hyderabad
# 17          Rajiv Gandhi International Stadium, Uppal   Sunrisers Hyderabad
# 18                              M Chinnaswamy Stadium   Sunrisers Hyderabad
# 19          Rajiv Gandhi International Stadium, Uppal   Sunrisers Hyderabad
# 20                           Wankhede Stadium, Mumbai  Lucknow Super Giants
# 21                          Brabourne Stadium, Mumbai  Lucknow Super Giants
# 22  Punjab Cricket Association IS Bindra Stadium, ...  Lucknow Super Giants
# 23                     Sawai Mansingh Stadium, Jaipur  Lucknow Super Giants
# 24  Rajiv Gandhi International Stadium, Uppal, Hyd...  Lucknow Super Giants
# 25                             Sawai Mansingh Stadium      Rajasthan Royals
# 26                             Sawai Mansingh Stadium      Rajasthan Royals
# 27          Rajiv Gandhi International Stadium, Uppal      Rajasthan Royals
# 28                             Sawai Mansingh Stadium      Rajasthan Royals
# 29                             Sawai Mansingh Stadium      Rajasthan Royals
#
#     balls_bowled  wickets  runs_conceded  overs_bowled
# 0             24        2             32      4.000000
# 1             14        1             10      2.333333
# 2             19        1             31      3.166667
# 3             13        1             15      2.166667
# 4             25        1             35      4.166667
# 5             25        2             36      4.166667
# 6             12        0             29      2.000000
# 7             12        0             17      2.000000
# 8             25        3             24      4.166667
# 9             12        1             21      2.000000
# 10             6        1              7      1.000000
# 11             6        0             12      1.000000
# 12            12        1             15      2.000000
# 13             5        0             14      0.833333
# 14             6        1             11      1.000000
# 15             6        0              5      1.000000
# 16            13        1             14      2.166667
# 17            12        2             19      2.000000
# 18            11        0             25      1.833333
# 19            12        1             14      2.000000
# 20             6        1              6      1.000000
# 21             6        1              5      1.000000
# 22             1        0              0      0.166667
# 23             6        0              6      1.000000
# 24             6        0             19      1.000000
# 25            24        0             29      4.000000
# 26            24        4             13      4.000000
# 27            24        1             20      4.000000
# 28            12        0             24      2.000000
# 29            18        0             14      3.000000

# %%
df_batter.to_csv("../data/ref/reference.csv",index=False)

# %%
# Sort data by batter and date to ensure temporal ordering for all time-based features
df_batter = df_batter.sort_values(['batter','date']).reset_index(drop=True)

# %%
df_batter.head()
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
#
#                              venue         bowling_team  batsman_runs  \
# 0                 Wankhede Stadium       Mumbai Indians             3
# 1                 Wankhede Stadium       Mumbai Indians             0
# 2                 Wankhede Stadium       Mumbai Indians             7
# 3  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             2
# 4  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             1
#
#    is_wicket
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0

# %% [markdown]
# ##### Calculation of rolling average

# %%
ipl =  ipl.sort_values(['batter','match_id','over','ball'])

df_batter['rolling_avg_5'] = (
    df_batter.groupby('batter')['batsman_runs']
      .rolling(window=5, min_periods=1)
      .mean()
      .shift(1)
      .reset_index(level=0, drop=True)
)   

print(df_batter.head(10))
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
# 5    548359  A Ashish Reddy        P Awana  2012-05-08
# 6    548359  A Ashish Reddy        P Kumar  2012-05-08
# 7    548359  A Ashish Reddy      PP Chawla  2012-05-08
# 8    548373  A Ashish Reddy        SW Tait  2012-05-18
# 9    548376  A Ashish Reddy  R Vinay Kumar  2012-05-20
#
#                                        venue                 bowling_team  \
# 0                           Wankhede Stadium               Mumbai Indians
# 1                           Wankhede Stadium               Mumbai Indians
# 2                           Wankhede Stadium               Mumbai Indians
# 3            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 4            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 5  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 6  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 7  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 8  Rajiv Gandhi International Stadium, Uppal             Rajasthan Royals
# 9  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
#
#    batsman_runs  is_wicket  rolling_avg_5
# 0             3          0            NaN
# 1             0          1       3.000000
# 2             7          0       1.500000
# 3             2          1       3.333333
# 4             1          0       3.000000
# 5             0          1       2.600000
# 6             6          0       2.000000
# 7             2          0       3.200000
# 8            10          0       2.200000
# 9             4          1       3.800000

# %% [markdown]
# ##### Calculation of venue average

# %%
df_batter['venue_avg'] = (
    df_batter.groupby(['batter', 'venue'])['batsman_runs']
      .expanding()
      .mean()
      .shift(1)
      .reset_index(level=[0,1], drop=True)
)

df_batter['venue_avg'] = df_batter['venue_avg'].fillna(0)

print(df_batter.head(5))
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
#
#                              venue         bowling_team  batsman_runs  \
# 0                 Wankhede Stadium       Mumbai Indians             3
# 1                 Wankhede Stadium       Mumbai Indians             0
# 2                 Wankhede Stadium       Mumbai Indians             7
# 3  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             2
# 4  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             1
#
#    is_wicket  rolling_avg_5  venue_avg
# 0          0            NaN   4.666667
# 1          1       3.000000   3.000000
# 2          0       1.500000   1.500000
# 3          1       3.333333   7.000000
# 4          0       3.000000   2.000000

# %% [markdown]
# ##### Calculation of player-to-team average

# %%
df_batter['pvt_avg'] = (
    df_batter.groupby(['batter', 'bowling_team'])['batsman_runs']
      .expanding()
      .mean()
      .shift(1) 
      .reset_index(level=[0,1], drop=True)
)

df_batter['pvt_avg'] = df_batter['pvt_avg'].fillna(0)
print(df_batter.head(5))
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
#
#                              venue         bowling_team  batsman_runs  \
# 0                 Wankhede Stadium       Mumbai Indians             3
# 1                 Wankhede Stadium       Mumbai Indians             0
# 2                 Wankhede Stadium       Mumbai Indians             7
# 3  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             2
# 4  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             1
#
#    is_wicket  rolling_avg_5  venue_avg  pvt_avg
# 0          0            NaN   4.666667      3.4
# 1          1       3.000000   3.000000      3.0
# 2          0       1.500000   1.500000      1.5
# 3          1       3.333333   7.000000      0.0
# 4          0       3.000000   2.000000      2.0

# %% [markdown]
# ##### Calculation of career avg

# %%
df_batter['career_avg'] = df_batter.groupby('batter')['batsman_runs'] \
                     .expanding() \
                     .mean() \
                     .shift(1) \
                     .reset_index(level=0, drop=True)

# Handle NaN values from shift operation (first match for each player)
df_batter['career_avg'] = df_batter['career_avg'].fillna(0)

print(df_batter.head(5))
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
#
#                              venue         bowling_team  batsman_runs  \
# 0                 Wankhede Stadium       Mumbai Indians             3
# 1                 Wankhede Stadium       Mumbai Indians             0
# 2                 Wankhede Stadium       Mumbai Indians             7
# 3  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             2
# 4  MA Chidambaram Stadium, Chepauk  Chennai Super Kings             1
#
#    is_wicket  rolling_avg_5  venue_avg  pvt_avg  career_avg
# 0          0            NaN   4.666667      3.4    0.000000
# 1          1       3.000000   3.000000      3.0    3.000000
# 2          0       1.500000   1.500000      1.5    1.500000
# 3          1       3.333333   7.000000      0.0    3.333333
# 4          0       3.000000   2.000000      2.0    3.000000

# %%
# first compute at ball level
ipl['pvp_avg_ball'] = (
    ipl.groupby(['batter', 'bowler'])['batsman_runs']
       .expanding()
       .mean()
       .shift(1)
       .reset_index(level=[0,1], drop=True)
)

ipl['pvp_avg_ball'] = ipl['pvp_avg_ball'].fillna(0)

# convert to match level
pvp_match = (
    ipl.groupby(['batter', 'match_id'])['pvp_avg_ball']
       .mean()
       .reset_index()
)

# Remove column if it exists before merging
if 'pvp_avg' in df_batter.columns:
    df_batter = df_batter.drop(columns=['pvp_avg'])
if 'pvp_avg_ball' in df_batter.columns:
    df_batter = df_batter.drop(columns=['pvp_avg_ball'])


# merge into df
df_batter = df_batter.merge(pvp_match, on=['batter','match_id'], how='left')
df_batter.rename(columns={'pvp_avg_ball':'pvp_avg'}, inplace=True)

print(df_batter.head(30))
# Out:
#     match_id          batter           bowler        date  \
# 0     548346  A Ashish Reddy     JEC Franklin  2012-04-29
# 1     548346  A Ashish Reddy         MM Patel  2012-04-29
# 2     548346  A Ashish Reddy      RJ Peterson  2012-04-29
# 3     548352  A Ashish Reddy    BW Hilfenhaus  2012-05-04
# 4     548352  A Ashish Reddy         DJ Bravo  2012-05-04
# 5     548359  A Ashish Reddy          P Awana  2012-05-08
# 6     548359  A Ashish Reddy          P Kumar  2012-05-08
# 7     548359  A Ashish Reddy        PP Chawla  2012-05-08
# 8     548373  A Ashish Reddy          SW Tait  2012-05-18
# 9     548376  A Ashish Reddy    R Vinay Kumar  2012-05-20
# 10    598000  A Ashish Reddy         AB Dinda  2013-04-05
# 11    598000  A Ashish Reddy          B Kumar  2013-04-05
# 12    598004  A Ashish Reddy         M Kartik  2013-04-07
# 13    598004  A Ashish Reddy    R Vinay Kumar  2013-04-07
# 14    598048  A Ashish Reddy    R Vinay Kumar  2013-04-09
# 15    598048  A Ashish Reddy         RP Singh  2013-04-09
# 16    598010  A Ashish Reddy         M Morkel  2013-04-12
# 17    598010  A Ashish Reddy         UT Yadav  2013-04-12
# 18    598013  A Ashish Reddy  SMSM Senanayake  2013-04-14
# 19    598013  A Ashish Reddy        SP Narine  2013-04-14
# 20    598018  A Ashish Reddy         AB Dinda  2013-04-17
# 21    598018  A Ashish Reddy       AD Mathews  2013-04-17
# 22    598018  A Ashish Reddy         MR Marsh  2013-04-17
# 23    598021  A Ashish Reddy    Azhar Mahmood  2013-04-19
# 24    598021  A Ashish Reddy          MS Gony  2013-04-19
# 25    598030  A Ashish Reddy        CH Morris  2013-04-25
# 26    598030  A Ashish Reddy         DJ Bravo  2013-04-25
# 27    598030  A Ashish Reddy        MM Sharma  2013-04-25
# 28    598032  A Ashish Reddy      JP Faulkner  2013-04-27
# 29    598032  A Ashish Reddy        KK Cooper  2013-04-27
#
#                                         venue                 bowling_team  \
# 0                            Wankhede Stadium               Mumbai Indians
# 1                            Wankhede Stadium               Mumbai Indians
# 2                            Wankhede Stadium               Mumbai Indians
# 3             MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 4             MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 5   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 6   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 7   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 8   Rajiv Gandhi International Stadium, Uppal             Rajasthan Royals
# 9   Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 10  Rajiv Gandhi International Stadium, Uppal                Pune Warriors
# 11  Rajiv Gandhi International Stadium, Uppal                Pune Warriors
# 12  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 13  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 14                      M Chinnaswamy Stadium  Royal Challengers Bangalore
# 15                      M Chinnaswamy Stadium  Royal Challengers Bangalore
# 16                           Feroz Shah Kotla             Delhi Daredevils
# 17                           Feroz Shah Kotla             Delhi Daredevils
# 18                               Eden Gardens        Kolkata Knight Riders
# 19                               Eden Gardens        Kolkata Knight Riders
# 20    Maharashtra Cricket Association Stadium                Pune Warriors
# 21    Maharashtra Cricket Association Stadium                Pune Warriors
# 22    Maharashtra Cricket Association Stadium                Pune Warriors
# 23  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 24  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 25            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 26            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 27            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 28                     Sawai Mansingh Stadium             Rajasthan Royals
# 29                     Sawai Mansingh Stadium             Rajasthan Royals
#
#     batsman_runs  is_wicket  rolling_avg_5  venue_avg    pvt_avg  career_avg  \
# 0              3          0            NaN   4.666667   3.400000    0.000000
# 1              0          1       3.000000   3.000000   3.000000    3.000000
# 2              7          0       1.500000   1.500000   1.500000    1.500000
# 3              2          1       3.333333   7.000000   0.000000    3.333333
# 4              1          0       3.000000   2.000000   2.000000    3.000000
# 5              0          1       2.600000   7.333333   4.500000    2.600000
# 6              6          0       2.000000   0.000000   0.000000    2.166667
# 7              2          0       3.200000   3.000000   3.000000    2.714286
# 8             10          0       2.200000   2.666667   5.200000    2.625000
# 9              4          1       3.800000   4.500000   5.285714    3.444444
# 10             6          0       4.400000   4.400000   4.500000    3.500000
# 11             1          0       5.600000   4.666667   6.000000    3.727273
# 12             6          0       4.600000   4.142857   4.000000    3.500000
# 13             8          1       5.400000   4.375000   5.000000    3.692308
# 14             2          0       5.000000   8.000000   6.000000    4.000000
# 15             1          1       4.600000   2.000000   5.000000    3.866667
# 16             4          1       3.600000   2.000000   6.428571    3.687500
# 17            12          0       4.200000   4.000000   4.000000    3.705882
# 18             3          1       5.400000   4.000000   4.625000    4.166667
# 19             1          0       4.400000   3.000000   3.000000    4.105263
# 20             3          0       4.200000   7.800000   3.500000    3.950000
# 21            13          0       4.600000   3.000000   3.333333    3.904762
# 22             3          0       6.400000   8.000000   5.750000    4.318182
# 23             2          0       4.600000   4.777778   2.666667    4.260870
# 24             5          0       4.400000   4.500000   2.500000    4.166667
# 25            10          0       5.200000   1.500000   1.500000    4.200000
# 26            19          0       6.600000   4.333333   4.333333    4.423077
# 27             7          0       7.800000   8.000000   8.000000    4.962963
# 28             2          0       8.600000   4.227273  10.000000    5.035714
# 29             8          0       8.600000   2.000000   6.000000    4.931034
#
#      pvp_avg
# 0   0.685606
# 1   0.685606
# 2   0.685606
# 3   1.733333
# 4   1.733333
# 5   0.708333
# 6   0.708333
# 7   0.708333
# 8   1.500000
# 9   1.400000
# 10  1.236111
# 11  1.236111
# 12  0.847421
# 13  0.847421
# 14  1.258333
# 15  1.258333
# 16  1.712963
# 17  1.712963
# 18  0.600000
# 19  0.600000
# 20  1.310000
# 21  1.310000
# 22  1.310000
# 23  0.952381
# 24  0.952381
# 25  1.562897
# 26  1.562897
# 27  1.562897
# 28  1.562121
# 29  1.562121

# %%
# Convert rolling_strike_rate_10 to match level
strike_match = (
    ipl.groupby(['batter', 'match_id'])['rolling_strike_rate_10']
       .mean()
       .reset_index()
)

df_batter = df_batter.merge(strike_match, on=['batter', 'match_id'], how='left')

df_batter['rolling_strike_rate_10'] = df_batter['rolling_strike_rate_10'].fillna(0)

# %%
# # Remove any existing total_match_runs columns before creating again
# cols_to_remove = [
#     'total_match_runs',
#     '
# 
#_x',
#     'total_match_runs_y'
# ]

# df_batter = df_batter.drop(
#     columns=[col for col in cols_to_remove if col in df_batter.columns]
# )

# %%
# total_runs = (
#     df_batter.groupby(['match_id', 'batter'])['batsman_runs']
#       .sum()
#       .reset_index()
#       .rename(columns={'batsman_runs': 'total_match_runs'})
# )

# # Step 2
# df_batter = df_batter.merge(
#     total_runs,
#     on=['match_id', 'batter'],
#     how='left'
# )

# # Step 3
# df_batter['total_match_runs'] = df_batter['total_match_runs'].fillna(0)
# print(df_batter.head(10))
# Out:
#    match_id          batter         bowler        date  \
# 0    548346  A Ashish Reddy   JEC Franklin  2012-04-29
# 1    548346  A Ashish Reddy       MM Patel  2012-04-29
# 2    548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3    548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4    548352  A Ashish Reddy       DJ Bravo  2012-05-04
# 5    548359  A Ashish Reddy        P Awana  2012-05-08
# 6    548359  A Ashish Reddy        P Kumar  2012-05-08
# 7    548359  A Ashish Reddy      PP Chawla  2012-05-08
# 8    548373  A Ashish Reddy        SW Tait  2012-05-18
# 9    548376  A Ashish Reddy  R Vinay Kumar  2012-05-20
#
#                                        venue                 bowling_team  \
# 0                           Wankhede Stadium               Mumbai Indians
# 1                           Wankhede Stadium               Mumbai Indians
# 2                           Wankhede Stadium               Mumbai Indians
# 3            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 4            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 5  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 6  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 7  Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 8  Rajiv Gandhi International Stadium, Uppal             Rajasthan Royals
# 9  Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
#
#    batsman_runs  is_wicket  rolling_avg_5  venue_avg   pvt_avg  career_avg  \
# 0             3          0            NaN   4.666667  3.400000    0.000000
# 1             0          1       3.000000   3.000000  3.000000    3.000000
# 2             7          0       1.500000   1.500000  1.500000    1.500000
# 3             2          1       3.333333   7.000000  0.000000    3.333333
# 4             1          0       3.000000   2.000000  2.000000    3.000000
# 5             0          1       2.600000   7.333333  4.500000    2.600000
# 6             6          0       2.000000   0.000000  0.000000    2.166667
# 7             2          0       3.200000   3.000000  3.000000    2.714286
# 8            10          0       2.200000   2.666667  5.200000    2.625000
# 9             4          1       3.800000   4.500000  5.285714    3.444444
#
#     pvp_avg  total_match_runs
# 0  0.685606                10
# 1  0.685606                10
# 2  0.685606                10
# 3  1.733333                 3
# 4  1.733333                 3
# 5  0.708333                 8
# 6  0.708333                 8
# 7  0.708333                 8
# 8  1.500000                10
# 9  1.400000                 4

# %% [markdown]
# ##### Target value(**)

# %%
df_batter['next_match_runs'] = df_batter.groupby('batter')['batsman_runs'].shift(-1)
df_batter = df_batter.dropna()
df_batter.head(10)
# Out:
#     match_id          batter         bowler        date  \
# 1     548346  A Ashish Reddy       MM Patel  2012-04-29
# 2     548346  A Ashish Reddy    RJ Peterson  2012-04-29
# 3     548352  A Ashish Reddy  BW Hilfenhaus  2012-05-04
# 4     548352  A Ashish Reddy       DJ Bravo  2012-05-04
# 5     548359  A Ashish Reddy        P Awana  2012-05-08
# 6     548359  A Ashish Reddy        P Kumar  2012-05-08
# 7     548359  A Ashish Reddy      PP Chawla  2012-05-08
# 8     548373  A Ashish Reddy        SW Tait  2012-05-18
# 9     548376  A Ashish Reddy  R Vinay Kumar  2012-05-20
# 10    598000  A Ashish Reddy       AB Dinda  2013-04-05
#
#                                         venue                 bowling_team  \
# 1                            Wankhede Stadium               Mumbai Indians
# 2                            Wankhede Stadium               Mumbai Indians
# 3             MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 4             MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 5   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 6   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 7   Rajiv Gandhi International Stadium, Uppal              Kings XI Punjab
# 8   Rajiv Gandhi International Stadium, Uppal             Rajasthan Royals
# 9   Rajiv Gandhi International Stadium, Uppal  Royal Challengers Bangalore
# 10  Rajiv Gandhi International Stadium, Uppal                Pune Warriors
#
#     batsman_runs  is_wicket  rolling_avg_5  venue_avg   pvt_avg  career_avg  \
# 1              0          1       3.000000   3.000000  3.000000    3.000000
# 2              7          0       1.500000   1.500000  1.500000    1.500000
# 3              2          1       3.333333   7.000000  0.000000    3.333333
# 4              1          0       3.000000   2.000000  2.000000    3.000000
# 5              0          1       2.600000   7.333333  4.500000    2.600000
# 6              6          0       2.000000   0.000000  0.000000    2.166667
# 7              2          0       3.200000   3.000000  3.000000    2.714286
# 8             10          0       2.200000   2.666667  5.200000    2.625000
# 9              4          1       3.800000   4.500000  5.285714    3.444444
# 10             6          0       4.400000   4.400000  4.500000    3.500000
#
#      pvp_avg  rolling_strike_rate_10  next_match_runs
# 1   0.685606               67.968254              7.0
# 2   0.685606               67.968254              2.0
# 3   1.733333              113.333333              1.0
# 4   1.733333              113.333333              0.0
# 5   0.708333              100.000000              6.0
# 6   0.708333              100.000000              2.0
# 7   0.708333              100.000000             10.0
# 8   1.500000              107.500000              4.0
# 9   1.400000              156.000000              6.0
# 10  1.236111              152.500000              1.0

# %% [markdown]
# ### Bowlers Features

# %%
df_bowler['rolling_avg_wickets'] = (
    df_bowler.groupby('bowler')['wickets']
             .rolling(window=5, min_periods=1)
             .mean()
             .shift(1)
             .reset_index(level=0, drop=True)
)

# %%
df_bowler['overs_bowled_last5'] = (
    df_bowler.groupby('bowler')['overs_bowled']
             .rolling(window=5, min_periods=1)
             .mean()
             .shift(1)
             .reset_index(level=0, drop=True)
)

# %%
df_bowler['venue_wicket_rate'] = (
    df_bowler.groupby(['bowler', 'venue'])['wickets']
             .expanding()
             .mean()
             .shift(1)
             .reset_index(level=[0,1], drop=True)
)

# %%
df_bowler['bowler_career_avg'] = (
    df_bowler.groupby('bowler')['wickets']
             .expanding()
             .mean()
             .shift(1)
             .reset_index(level=0, drop=True)
)

# %%
df_bowler[
    ['rolling_avg_wickets','overs_bowled_last5',
     'venue_wicket_rate','bowler_career_avg']
] = df_bowler[
    ['rolling_avg_wickets','overs_bowled_last5',
     'venue_wicket_rate','bowler_career_avg']
].fillna(0)

# %%
df_bowler['next_match_wicket'] = (
    df_bowler.groupby('bowler')['wickets']
             .shift(-1)
)

df_bowler = df_bowler.dropna()

# %% [markdown]
# ##### Feature Selection for the ML model (**)

# %%
features_batsman = df_batter[
    ['rolling_avg_5','venue_avg','pvt_avg','pvp_avg','career_avg','rolling_strike_rate_10']
]

labels_batsman = df_batter['next_match_runs']


features_bowler = df_bowler[
    ['rolling_avg_wickets',
     'overs_bowled_last5',
     'venue_wicket_rate',
     'bowler_career_avg']
]

labels_bowler = df_bowler['next_match_wicket']

# %%
df_batter = df_batter.sort_values('date').reset_index(drop=True)

# %% [markdown]
# #### Batsman split

# %%
df_batter = df_batter.sort_values('date').reset_index(drop=True)

split_b = int(len(df_batter) * 0.8)

Xb_train = features_batsman.iloc[:split_b]
Xb_test  = features_batsman.iloc[split_b:]

yb_train = labels_batsman.iloc[:split_b]
yb_test  = labels_batsman.iloc[split_b:]

# %% [markdown]
# #### Bowler split

# %%
df_bowler = df_bowler.sort_values('date').reset_index(drop=True)

split_w = int(len(df_bowler) * 0.8)

Xw_train = features_bowler.iloc[:split_w]
Xw_test  = features_bowler.iloc[split_w:]

yw_train = labels_bowler.iloc[:split_w]
yw_test  = labels_bowler.iloc[split_w:]

# %%
batter_pipeline = Pipeline([
    ('scaler', StandardScaler())
])

batter_pipeline.fit(Xb_train)
joblib.dump(batter_pipeline, "../scripts/batter_feature_pipeline.pkl")
# Out:
# ['../scripts/batter_feature_pipeline.pkl']

# %%
bowler_pipeline = Pipeline([
    ('scaler', StandardScaler())
])

bowler_pipeline.fit(Xw_train)
joblib.dump(bowler_pipeline, "../scripts/bowler_feature_pipeline.pkl")
# Out:
# ['../scripts/bowler_feature_pipeline.pkl']

# %%
final_batter_df = df_batter[
    [
        'batter','date','venue','bowling_team',
        'rolling_avg_5','venue_avg','pvt_avg','pvp_avg','career_avg','rolling_strike_rate_10',
        'next_match_runs',
    ]
]

final_batter_df.to_csv(
    "../data/cleaned/batter_dataset.csv",
    index=False
)

# %%
final_bowler_df = df_bowler[
    [
        'bowler','date','venue','bowling_team',
        'rolling_avg_wickets','overs_bowled_last5',
        'venue_wicket_rate','bowler_career_avg',
        'next_match_wicket'
    ]
]

final_bowler_df.to_csv(
    "../data/cleaned/bowler_dataset.csv",
    index=False
)
