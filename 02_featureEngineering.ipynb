# %%
import pandas as pd

ipl = pd.read_csv("../data/cleaned/ipl_cleaned.csv")

ipl.head()
# Out:
#         id  innings  overs  ball_number       batter          bowler  \
# 0  1312200        1      0            1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0            2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0            3   JC Buttler  Mohammed Shami
# 3  1312200        1      0            4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0            5  YBK Jaiswal  Mohammed Shami
#
#    non_striker extra_type  batsman_run  extras_run  ...  non_boundary  \
# 0   JC Buttler        NaN            0           0  ...             0
# 1   JC Buttler    legbyes            0           1  ...             0
# 2  YBK Jaiswal        NaN            1           0  ...             0
# 3   JC Buttler        NaN            0           0  ...             0
# 4   JC Buttler        NaN            0           0  ...             0
#
#    iswicket_delivery  player_out dismisal_kind fielders_involved  \
# 0                  0         NaN           NaN               NaN
# 1                  0         NaN           NaN               NaN
# 2                  0         NaN           NaN               NaN
# 3                  0         NaN           NaN               NaN
# 4                  0         NaN           NaN               NaN
#
#        batting_team        date                             venue  \
# 0  rajasthan royals  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 1  rajasthan royals  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 2  rajasthan royals  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 3  rajasthan royals  2022-05-29  Narendra Modi Stadium, Ahmedabad
# 4  rajasthan royals  2022-05-29  Narendra Modi Stadium, Ahmedabad
#
#               team1           team2
# 0  rajasthan royals  gujarat titans
# 1  rajasthan royals  gujarat titans
# 2  rajasthan royals  gujarat titans
# 3  rajasthan royals  gujarat titans
# 4  rajasthan royals  gujarat titans
#
# [5 rows x 21 columns]

# %%
batsman_match = (
    ipl.groupby(["id", "date", "venue", "batter"])
    .agg(
        runs_scored=("batsman_run", "sum"),
        balls_faced=("batsman_run", "count")
    )
    .reset_index()
)

# %%
bowler_match = (
    ipl.groupby(["id", "date", "venue", "bowler"])
    .agg(
        wickets_taken=("iswicket_delivery", "sum"),
        balls_bowled=("iswicket_delivery", "count")
    )
    .reset_index()
)

# %%
batsman_match = batsman_match.sort_values("date")
bowler_match = bowler_match.sort_values("date")

# %%
batsman_match["runs_last_5"] = (
    batsman_match
    .groupby("batter")["runs_scored"]
    .rolling(5, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)

# %%
bowler_match["wickets_last_5"] = (
    bowler_match
    .groupby("bowler")["wickets_taken"]
    .rolling(5, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)

# %%
batsman_match["venue_avg_runs"] = (
    batsman_match
    .groupby(["batter", "venue"])["runs_scored"]
    .transform("mean")
)

# %%
bowler_match["venue_avg_wickets"] = (
    bowler_match
    .groupby(["bowler", "venue"])["wickets_taken"]
    .transform("mean")
)

# %%
batsman_match["career_avg_runs"] = (
    batsman_match
    .groupby("batter")["runs_scored"]
    .transform("mean")
)

# %%
bowler_match["career_avg_wickets"] = (
    bowler_match
    .groupby("bowler")["wickets_taken"]
    .transform("mean")
)

# %%
batsman_match["target_runs"] = (
    batsman_match
    .groupby("batter")["runs_scored"]
    .shift(-1)
)

# %%
bowler_match["target_wickets"] = (
    bowler_match
    .groupby("bowler")["wickets_taken"]
    .shift(-1)
)

# %%
batsman_match.dropna(subset=["target_runs"], inplace=True)
bowler_match.dropna(subset=["target_wickets"], inplace=True)

# %%
batsman_features = batsman_match[
    [
        "runs_last_5",
        "venue_avg_runs",
        "career_avg_runs"
    ]
]

batsman_target = batsman_match["target_runs"]

# %%
bowler_features = bowler_match[
    [
        "wickets_last_5",
        "venue_avg_wickets",
        "career_avg_wickets"
    ]
]

bowler_target = bowler_match["target_wickets"]

# %%
batsman_match.to_csv("../data/processed/batsman_features.csv", index=False)
bowler_match.to_csv("../data/processed/bowler_features.csv", index=False)
